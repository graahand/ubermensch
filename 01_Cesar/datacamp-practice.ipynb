# %% [markdown]
# ## Output of this code

# %% [markdown]
# churn[churn["credit_score"] < 600].head()

# %% [markdown]
# This code filters the DataFrame churn to include only rows where the value in the "credit_score" column is less than 600, and then displays the first five rows of the resulting subset using the .head() method.

# %% [markdown]
# Which plot is best used to show the relationships between categorical variabe and a numeric variable?
#
# Bar  plot, numeric data as bar and categories

# %%
print(churn.isna().sum())
